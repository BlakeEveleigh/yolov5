# %%
# %pip install -r requirements.txt
# %pip install dill
# %pip install datasets fastparquet pyarrow pytorch-lightning torchvision torchmetrics xgboost PyTorch TensorFlow
# %pip install matplotlib
# %pip install pillow
# %pip install pandas
import pandas as pd
import matplotlib.pyplot as plt
import torch
import utils
from PIL import Image
import os

display = utils.notebook_init()  # checks
# Out:
# YOLOv5  2023-10-12 Python-3.10.13 torch-2.0.1 CPU
# Setup complete  (8 CPUs, 7.9 GB RAM, 115.9/117.9 GB disk)

# %%
# !python train.py --data cocoDrone.yaml --epochs 100 --weights '' --cfg yolov5n.yaml  --batch-size 32
# Out:
# train: weights='', cfg=yolov5n.yaml, data=cocoDrone.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-231-g4494ebc1 Python-3.9.17 torch-2.0.1+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1      8118  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# YOLOv5n summary: 214 layers, 1765270 parameters, 1765270 gradients, 4.2 GFLOPs
#
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
#
# train: Scanning C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\train2017...:   0%|          | 0/49 [00:00<?, ?it/s]
# train: Scanning C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\train2017... 0 images, 0 backgrounds, 1 corrupt:   2%|2         | 1/49 [00:30<24:34, 30.71s/it]
# train: Scanning C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\train2017... 5 images, 0 backgrounds, 1 corrupt:  12%|#2        | 6/49 [00:30<02:42,  3.79s/it]
# train: Scanning C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\train2017... 22 images, 0 backgrounds, 12 corrupt:  69%|######9   | 34/49 [00:30<00:07,  2.10it/s]
# train: Scanning C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\train2017... 28 images, 0 backgrounds, 21 corrupt: 100%|##########| 49/49 [00:30<00:00,  1.58it/s]
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\001.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\001.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0017.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0017.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0018.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0018.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0019.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0019.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0021.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0021.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0023.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0023.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0027.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0027.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\003.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\003.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0031.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0031.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0036.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0036.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0038.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0038.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\004.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\004.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0041.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0041.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0043.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0043.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0045.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0045.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0047.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0047.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\005.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\005.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\006.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\006.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\007.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\007.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\008.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\008.jpg'
# train: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\009.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\009.jpg'
# train: WARNING  Cache directory C:\Users\andym\Documents\GitHub\yolov5\datasets\coco is not writeable: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\train2017.cache.npy' -> 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\train2017.cache'
#
# val: Scanning C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\train2017...:   0%|          | 0/49 [00:00<?, ?it/s]
# val: Scanning C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\train2017... 0 images, 0 backgrounds, 1 corrupt:   2%|2         | 1/49 [00:31<25:20, 31.69s/it]
# val: Scanning C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\train2017... 28 images, 0 backgrounds, 21 corrupt: 100%|##########| 49/49 [00:31<00:00,  1.54it/s]
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\001.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\001.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0017.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0017.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0018.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0018.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0019.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0019.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0021.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0021.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0023.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0023.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0027.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0027.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\003.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\003.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0031.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0031.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0036.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0036.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0038.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0038.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\004.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\004.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0041.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0041.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0043.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0043.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0045.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0045.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\0047.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\0047.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\005.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\005.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\006.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\006.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\007.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\007.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\008.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\008.jpg'
# val: WARNING  C:\Users\andym\Documents\GitHub\yolov5\datasets\coco\drone_dataset_yolo\dataset_txt\009.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\drone_dataset_yolo\\dataset_txt\\009.jpg'
# val: WARNING  Cache directory C:\Users\andym\Documents\GitHub\yolov5\datasets\coco is not writeable: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\train2017.cache.npy' -> 'C:\\Users\\andym\\Documents\\GitHub\\yolov5\\datasets\\coco\\train2017.cache'
#
# AutoAnchor: 2.55 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Plotting labels to runs\train\exp9\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\train\exp9
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#         0/2         0G     0.1143    0.03236          0         55        640:   0%|          | 0/2 [00:17<?, ?it/s]
#         0/2         0G     0.1143    0.03236          0         55        640:  50%|#####     | 1/2 [00:30<00:30, 30.77s/it]
#         0/2         0G     0.1133    0.03082          0         32        640:  50%|#####     | 1/2 [00:40<00:30, 30.77s/it]
#         0/2         0G     0.1133    0.03082          0         32        640: 100%|##########| 2/2 [00:40<00:00, 18.15s/it]
#         0/2         0G     0.1133    0.03082          0         32        640: 100%|##########| 2/2 [00:40<00:00, 20.04s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 1.900s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:12<00:00, 12.67s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:12<00:00, 12.67s/it]
#                    all         28         31          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#         1/2         0G     0.1123    0.02741          0         37        640:   0%|          | 0/2 [00:26<?, ?it/s]
#         1/2         0G     0.1123    0.02741          0         37        640:  50%|#####     | 1/2 [00:26<00:26, 26.25s/it]
#         1/2         0G     0.1127    0.02939          0         34        640:  50%|#####     | 1/2 [00:36<00:26, 26.25s/it]
#         1/2         0G     0.1127    0.02939          0         34        640: 100%|##########| 2/2 [00:36<00:00, 16.85s/it]
#         1/2         0G     0.1127    0.02939          0         34        640: 100%|##########| 2/2 [00:36<00:00, 18.26s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 1.900s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:12<00:00, 12.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:12<00:00, 12.14s/it]
#                    all         28         31          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#         2/2         0G      0.115    0.03273          0         53        640:   0%|          | 0/2 [00:12<?, ?it/s]
#         2/2         0G      0.115    0.03273          0         53        640:  50%|#####     | 1/2 [00:12<00:12, 12.85s/it]
#         2/2         0G     0.1166    0.03123          0         34        640:  50%|#####     | 1/2 [00:21<00:12, 12.85s/it]
#         2/2         0G     0.1166    0.03123          0         34        640: 100%|##########| 2/2 [00:21<00:00, 10.67s/it]
#         2/2         0G     0.1166    0.03123          0         34        640: 100%|##########| 2/2 [00:21<00:00, 11.00s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 1.900s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:12<00:00, 12.88s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:12<00:00, 12.88s/it]
#                    all         28         31          0          0          0          0
#
# 3 epochs completed in 0.040 hours.
# Optimizer stripped from runs\train\exp9\weights\last.pt, 3.9MB
# Optimizer stripped from runs\train\exp9\weights\best.pt, 3.9MB
#
# Validating runs\train\exp9\weights\best.pt...
# Fusing layers...
# YOLOv5n summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 1.900s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:12<00:00, 12.75s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 1/1 [00:12<00:00, 12.75s/it]
#                    all         28         31          0          0          0          0
# Results saved to runs\train\exp9

# %%
# !python detect.py --weights runs/train/exp36/weights/best.pt --img 640 --conf 0.25 --source data/images/Drones
# Out:
# detect: weights=['runs/train/exp36/weights/best.pt'], source=data/images/Drones, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
# YOLOv5  2023-10-12 Python-3.10.13 torch-2.0.1 CPU
#
# Traceback (most recent call last):
#   File "C:\Users\blake\yolov5\detect.py", line 285, in <module>
#     main(opt)
#   File "C:\Users\blake\yolov5\detect.py", line 280, in main
#     run(**vars(opt))
#   File "C:\Users\blake\anaconda3\envs\workingone\lib\site-packages\torch\utils\_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "C:\Users\blake\yolov5\detect.py", line 101, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "C:\Users\blake\yolov5\models\common.py", line 356, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#   File "C:\Users\blake\yolov5\models\experimental.py", line 79, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "C:\Users\blake\anaconda3\envs\workingone\lib\site-packages\torch\serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "C:\Users\blake\anaconda3\envs\workingone\lib\site-packages\torch\serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "C:\Users\blake\anaconda3\envs\workingone\lib\site-packages\torch\serialization.py", line 252, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\train\\exp36\\weights\\best.pt'

# %%
base_path = 'runs/detect'
most_recent_file = None
most_recent_time = 0

for entry in os.scandir(directory_path):
    if entry.is_dir():
        # Get the modification time of the subdirectory
        mod_time = entry.stat().st_mtime_ns
        if mod_time > most_recent_time:
            # Update the most recent directory and its modification time
            most_recent_directory = entry.name
            most_recent_time = mod_time
            
if most_recent_directory:
    most_recent_directory_path = os.path.join(base_path, most_recent_directory)

    # List image files in the most recent directory
    image_files = [entry.path for entry in os.scandir(most_recent_directory_path) if entry.is_file() and entry.name.lower().endswith(('.jpg', '.jpeg', '.png'))]

    if image_files:
        # Display every image in the most recent directory
        for image_path in image_files:
            img = mpimg.imread(image_path)
            plt.imshow(img)
            plt.axis('off')
            plt.show()

# %%
csv_file = "runs/train/exp36/results.csv"
df = pd.read_csv(csv_file)
print(df.columns)


# Extract the "train/box_loss" values and the epoch numbers
box_loss = df['      train/box_loss']
epochs = df['               epoch']

# Create the line graph
plt.figure(figsize=(10, 6))  # Set the figure size
plt.plot(epochs, box_loss, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("Box Loss")
plt.title("Train/Box Loss Over Epochs")
plt.grid(True)  # Add grid lines (optional)
plt.show()
# Out:
# Index(['               epoch', '      train/box_loss', '      train/obj_loss',
#        '      train/cls_loss', '   metrics/precision', '      metrics/recall',
#        '     metrics/mAP_0.5', 'metrics/mAP_0.5:0.95', '        val/box_loss',
#        '        val/obj_loss', '        val/cls_loss', '               x/lr0',
#        '               x/lr1', '               x/lr2'],
#       dtype='object')

# %%
obj_loss = df['      train/obj_loss']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, obj_loss, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("obj_loss")
plt.title("obj Loss Over Epochs")
plt.grid(True)  
plt.show()

# %%
Precision = df['   metrics/precision']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, Precision, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("Precision")
plt.title("Precision Over Epochs")
plt.grid(True)  
plt.show()

# %%
Recall = df['      metrics/recall']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, Recall, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("Recall")
plt.title("Recall Over Epochs")
plt.grid(True)  
plt.show()

# %%
mAP05 = df['     metrics/mAP_0.5']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, mAP05, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("mAP05")
plt.title("mAP05 Over Epochs")
plt.grid(True)  
plt.show()

# %%
mAP095 = df['metrics/mAP_0.5:0.95']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, mAP095, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("mAP0.5:0.95")
plt.title("mAP0.5:0.95 Over Epochs")
plt.grid(True)  
plt.show()

# %%
precision = df['   metrics/precision']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, precision, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("precision")
plt.title("precision Over Epochs")
plt.grid(True)  
plt.show()

# %%
recall = df['      metrics/recall']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, recall, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("recall")
plt.title("recall Over Epochs")
plt.grid(True)  
plt.show()

# %%
box_loss = df['      train/box_loss']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, box_loss, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("box_loss")
plt.title("box_loss Over Epochs")
plt.grid(True)  
plt.show()

# %%
obj_loss = df['      train/obj_loss']
epochs = df['               epoch']


plt.figure(figsize=(10, 6)) 
plt.plot(epochs, obj_loss, marker='o', linestyle='-')
plt.xlabel("Epoch")
plt.ylabel("obj_loss")
plt.title("obj_loss Over Epochs")
plt.grid(True)  
plt.show()

# %%
# !python train.py --data cocoStarfish.yaml --epochs 100 --weights '' --cfg yolov5n.yaml  --batch-size 16

# %%
# !python detect.py --weights runs/train/exp36/weights/best.pt   --img 640 --conf 0.25 --source data/images/Drones
# Out:
# detect: weights=['runs/train/exp36/weights/best.pt'], source=data/images/Drones, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-233-g1877c8ce Python-3.10.13 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/18 C:\Users\blake\yolov5\data\images\Drones\Drone1.jpg: 480x640 (no detections), 215.1ms
# image 2/18 C:\Users\blake\yolov5\data\images\Drones\Drone2.jpg: 640x640 (no detections), 286.9ms
# image 3/18 C:\Users\blake\yolov5\data\images\Drones\pic_215.jpg: 320x640 1 Drone, 155.0ms
# image 4/18 C:\Users\blake\yolov5\data\images\Drones\pic_220.jpg: 448x640 1 Drone, 197.0ms
# image 5/18 C:\Users\blake\yolov5\data\images\Drones\pic_229.jpg: 384x640 (no detections), 176.0ms
# image 6/18 C:\Users\blake\yolov5\data\images\Drones\pic_239.jpg: 480x640 (no detections), 200.0ms
# image 7/18 C:\Users\blake\yolov5\data\images\Drones\pic_277.jpg: 352x640 2 Drones, 164.0ms
# image 8/18 C:\Users\blake\yolov5\data\images\Drones\pic_290.jpg: 480x640 (no detections), 198.4ms
# image 9/18 C:\Users\blake\yolov5\data\images\Drones\pic_442.jpg: 512x640 3 Drones, 229.8ms
# image 10/18 C:\Users\blake\yolov5\data\images\Drones\pic_571.jpg: 448x640 (no detections), 189.9ms
# image 11/18 C:\Users\blake\yolov5\data\images\Drones\pic_573.jpg: 384x640 (no detections), 170.9ms
# image 12/18 C:\Users\blake\yolov5\data\images\Drones\pic_579.jpg: 640x640 (no detections), 280.0ms
# image 13/18 C:\Users\blake\yolov5\data\images\Drones\pic_580.jpg: 640x640 (no detections), 271.9ms
# image 14/18 C:\Users\blake\yolov5\data\images\Drones\pic_622.jpg: 448x640 (no detections), 193.0ms
# image 15/18 C:\Users\blake\yolov5\data\images\Drones\pic_623.jpg: 384x640 (no detections), 167.9ms
# image 16/18 C:\Users\blake\yolov5\data\images\Drones\pic_632.jpg: 384x640 (no detections), 172.0ms
# image 17/18 C:\Users\blake\yolov5\data\images\Drones\pic_637.jpg: 448x640 2 Drones, 192.0ms
# image 18/18 C:\Users\blake\yolov5\data\images\Drones\pic_645.jpg: 416x640 1 Drone, 186.1ms
# Speed: 0.5ms pre-process, 202.6ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp27
